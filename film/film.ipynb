# %%
import pandas as pd
import matplotlib as plt
film_data = pd.read_csv('film.csv', index_col = 0)
film_data.head()
# Out:
#                     title                                        description  \
# film_id
# 1        ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist...
# 2          ACE GOLDFINGER  A Astounding Epistle of a Database Administrat...
# 3        ADAPTATION HOLES  A Astounding Reflection of a Lumberjack And a ...
# 4        AFFAIR PREJUDICE  A Fanciful Documentary of a Frisbee And a Lumb...
# 5             AFRICAN EGG  A Fast-Paced Documentary of a Pastry Chef And ...
#
#          release_year  language_id  original_language_id  rental_duration  \
# film_id
# 1                2006            1                   NaN                6
# 2                2006            1                   NaN                3
# 3                2006            1                   NaN                7
# 4                2006            1                   NaN                5
# 5                2006            1                   NaN                6
#
# ...

# %%
film_data.describe(include="all")
# Out:
#                title                                        description  \
# count           1000                                               1000
# unique          1000                                               1000
# top     MONEY HAROLD  A Fanciful Panorama of a Mad Scientist And a W...
# freq               1                                                  1
# mean             NaN                                                NaN
# std              NaN                                                NaN
# min              NaN                                                NaN
# 25%              NaN                                                NaN
# 50%              NaN                                                NaN
# 75%              NaN                                                NaN
# max              NaN                                                NaN
#
#         release_year  language_id  original_language_id  rental_duration  \
# ...

# %% [markdown]
# All movies were release in 2006

# %%
# Match language
# No record for original language, hence it can be removed
# Group by rental duration
# Group by rental_rate
# Create a duration_range
# Group by duration_range
# Group by replacement cost
# Group by rating
# Group by special_feature
# Mine the release month which is assumed to be gotten from the latest update_date
