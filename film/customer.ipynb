# %%
import pandas as pd
import matplotlib as plt
customer_data = pd.read_csv('customer.csv', index_col = 0)
customer_data.head()
# Out:
#              store_id first_name last_name  \
# customer_id
# 1                   1       MARY     SMITH
# 2                   1   PATRICIA   JOHNSON
# 3                   1      LINDA  WILLIAMS
# 4                   2    BARBARA     JONES
# 5                   1  ELIZABETH     BROWN
#
#                                            email  address_id  active  \
# customer_id
# 1                  MARY.SMITH@sakilacustomer.org           5       1
# 2            PATRICIA.JOHNSON@sakilacustomer.org           6       1
# 3              LINDA.WILLIAMS@sakilacustomer.org           7       1
# 4               BARBARA.JONES@sakilacustomer.org           8       1
# 5             ELIZABETH.BROWN@sakilacustomer.org           9       1
#
#                      create_date          last_update
# customer_id
# 1            2006-02-14 22:04:36  2006-02-15 04:57:20
# 2            2006-02-14 22:04:36  2006-02-15 04:57:20
# 3            2006-02-14 22:04:36  2006-02-15 04:57:20
# ...

# %%
customer_data.describe(include='all')
# Out:
#           store_id first_name last_name                            email  \
# count   599.000000        599       599                              599
# unique         NaN        591       599                              599
# top            NaN      JAMIE    GRAHAM  JILL.HAWKINS@sakilacustomer.org
# freq           NaN          2         1                                1
# mean      1.455760        NaN       NaN                              NaN
# std       0.498455        NaN       NaN                              NaN
# min       1.000000        NaN       NaN                              NaN
# 25%       1.000000        NaN       NaN                              NaN
# 50%       1.000000        NaN       NaN                              NaN
# 75%       2.000000        NaN       NaN                              NaN
# max       2.000000        NaN       NaN                              NaN
#
#         address_id      active          create_date          last_update
# ...

# %%
customer_data['full_name'] = customer_data['first_name'] + ' ' + customer_data['last_name']

# %%
customer_data.describe(include='all')
# Out:
#           store_id first_name last_name                            email  \
# count   599.000000        599       599                              599
# unique         NaN        591       599                              599
# top            NaN      JAMIE    GRAHAM  JILL.HAWKINS@sakilacustomer.org
# freq           NaN          2         1                                1
# mean      1.455760        NaN       NaN                              NaN
# std       0.498455        NaN       NaN                              NaN
# min       1.000000        NaN       NaN                              NaN
# 25%       1.000000        NaN       NaN                              NaN
# 50%       1.000000        NaN       NaN                              NaN
# 75%       2.000000        NaN       NaN                              NaN
# max       2.000000        NaN       NaN                              NaN
#
#         address_id      active          create_date          last_update  \
# ...

# %% [markdown]
# There no duplicate entery
# There was a general update on the 15th of February on all records

# %%
# Group by store
# Group by creation date
# Group by store and creation_date
# Match with the store name
